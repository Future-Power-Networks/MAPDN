# %%
import numpy as np
mask = np.load("graph_cache/case33/adj_mask.npy")
prior = np.load("graph_cache/case33/edge_prior.npy")
n = mask.shape[0]
density = mask.sum() / (n * (n - 1))
print("mask shape:", mask.shape)
print("mask density:", density)
print("prior min/max/mean:", prior.min(), prior.max(), prior.mean())
# Out:
# mask shape: (6, 6)
# mask density: 0.8
# prior min/max/mean: 0.0 1.0 0.41571486
